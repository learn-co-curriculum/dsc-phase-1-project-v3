# %% [markdown]
# # IMPORTANT
# This notebook runs off of the Data_Exploration_Cleaning notebook's kernel, you MUST run all cells in that notebook before using this notebook and then set this kernel to run off of Data_Exploration_Cleaning's kernel

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#useful dataframes created in cleaning and processing
engine_type
purpose_of_flight
weather_condition
broad_phase_of_flight
engine_num
# Out:
#                    Percent.Serious.and.Fatal  Percent.Uninjured
# Number.of.Engines
# 2.0                                30.873148          65.546574
# 1.0                                24.508043          65.909508
# 4.0                                 5.105251          94.851804

# %%
#


x1 = top_ten_small_planes_model
y1 = top_ten_small_planes_percmajor

x2 = list(by_model_final_over_20.index)
y2 = list(by_model_final_over_20['Percent.Serious.and.Fatal'])

fig, ax = plt.subplots(1, 2, figsize = (12,6))

# Plot data

ax[0].bar(x1, y1)
ax[1].bar(x2, y2)

# Customize appearance
ax[0].tick_params(axis="x", labelrotation=90)
ax[0].set_ylabel('Percent Serious or Fatal')
ax[0].set_xlabel("Plane Model")
ax[0].set_title("Small Planes") 
ax[1].tick_params(axis="x", labelrotation=90)
ax[1].set_ylabel("Percent Serious or Fatal")
ax[1].set_xlabel("Plane Model")
ax[1].set_title("Large Planes") 
plt.ylim(0,12)
# Out:
# (0.0, 12.0)

# %%
df_trimmed
# Out:
#              Event.Id Investigation.Type  Event.Date Location Latitude  \
# 17     20020917X01656           Accident  1982-01-02       AK      NaN
# 18     20020917X02481           Accident  1982-01-02       PA      NaN
# 20     20020917X01894           Accident  1982-01-02       MI      NaN
# 21     20020917X01776           Accident  1982-01-02       MI      NaN
# 29     20020917X02155           Accident  1982-01-03       CA      NaN
# ...               ...                ...         ...      ...      ...
# 90303  20221206106424           Accident  2022-12-04       MN  046936N
# 90305  20221206106419           Accident  2022-12-05       OK  352933N
# 90316  20221213106447           Accident  2022-12-08       GA  332754N
# 90324  20221212106444           Accident  2022-12-12       TN  355745N
# 90332  20221215106463           Accident  2022-12-14       PR  182724N
#
#       Longitude Injury.Severity Aircraft.damage                Make  \
# 17          NaN        Fatal(3)       Destroyed              cessna
# 18          NaN       Non-Fatal     Substantial              cessna
# 20          NaN       Non-Fatal     Substantial              cessna
# 21          NaN       Non-Fatal     Substantial              cessna
# 29          NaN       Non-Fatal     Substantial            bellanca
# ...         ...             ...             ...                 ...
# 90303  0096524W       Non-Fatal     Substantial              cessna
# 90305  0974927W           Fatal       Destroyed               beech
# 90316  0835049W       Non-Fatal     Substantial               beech
# 90324  0835218W       Non-Fatal     Substantial              cessna
# 90332  0066554W       Non-Fatal     Substantial  cirrus design corp
#
#        Number.of.Engines  ... Total.Uninjured Weather.Condition  \
# 17                   1.0  ...             0.0               VMC
# 18                   1.0  ...             1.0               VMC
# 20                   1.0  ...             1.0               VMC
# 21                   1.0  ...             2.0               VMC
# 29                   1.0  ...             0.0               VMC
# ...                  ...  ...             ...               ...
# 90303                1.0  ...             2.0               VMC
# 90305                1.0  ...             0.0               VMC
# 90316                1.0  ...             2.0               VMC
# 90324                1.0  ...             1.0               VMC
# 90332                1.0  ...             1.0               VMC
#
#        Broad.phase.of.flight   Report.Status  Num.Passenger  Total.Injured  \
# 17                   Unknown  Probable Cause            3.0            3.0
# 18                      Taxi  Probable Cause            1.0            0.0
# 20                   Takeoff  Probable Cause            1.0            0.0
# 21                  Approach  Probable Cause            2.0            0.0
# 29               Maneuvering  Probable Cause            2.0            2.0
# ...                      ...             ...            ...            ...
# 90303                    NaN             NaN            2.0            0.0
# 90305                    NaN             NaN            3.0            3.0
# 90316                    NaN             NaN            2.0            0.0
# 90324                    NaN             NaN            1.0            0.0
# 90332                    NaN             NaN            1.0            0.0
#
#       Percent.Serious.and.Fatal Percent.Uninjured              Make.Model  \
# 17                        100.0               0.0               cessna180
# 18                          0.0             100.0               cessna172
# 20                          0.0             100.0               cessna152
# 21                          0.0             100.0              cessna150L
# 29                          0.0               0.0           bellanca7GCBC
# ...                         ...               ...                     ...
# 90303                       0.0             100.0             cessnaA185F
# 90305                     100.0               0.0               beechF33A
# 90316                       0.0             100.0                beechA36
# 90324                       0.0             100.0               cessna172
# 90332                       0.0             100.0  cirrus design corpSR22
#
#        Max.Capacity
# 17                6
# 18                4
# 20                3
# 21                2
# 29                3
# ...             ...
# 90303             6
# 90305             5
# 90316             4
# 90324             4
# 90332             5
#
# [11376 rows x 25 columns]

# %%
#bar graph by engine type
engine_type = engine_type.drop(['Turbo Jet', 'UNK', 'Unknown'])

x = list(engine_type.index)
y = list(engine_type['Percent.Serious.and.Fatal'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percent Serious or Fatal")

ax.set_xlabel('Engine Type')

ax.set_title("Percent Serious or Fatal by Engine Type")
# Out:
# Text(0.5, 1.0, 'Percent Serious or Fatal by Engine Type')

# %%
#bar graph for Purpose of flight

x = list(purpose_of_flight.index)
y = list(purpose_of_flight['Percent.Serious.and.Fatal'])
fig, ax = plt.subplots()

#Plot data
ax.bar(x, y)

#Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percent Serious or Fatal")

ax.set_xlabel('Purpose of Flight')

ax.set_title("Percent Serious or Fatal by Purpose of Flight")

plt.show()

# %%
#Bar graph by weather condition
weather_condition.drop(['Unk', 'UNK'], inplace = True)

x = list(weather_condition.index)
y = list(weather_condition['Percent.Serious.and.Fatal'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percent Serious or Fatal")

ax.set_xlabel('Weather Condition')

ax.set_title("Percent Serious or Fatal by Weather Condition")
# Out:
# Text(0.5, 1.0, 'Percent Serious or Fatal by Weather Condition')

# %%
weather_condition
# Out:
#                    Percent.Serious.and.Fatal  Percent.Uninjured
# Weather.Condition
# IMC                                66.797131          23.951785
# VMC                                21.970551          68.789256

# %%
#broad phase of flight bar graph
broad_phase_of_flight.drop(['Unknown'], inplace = True)

x = list(broad_phase_of_flight.index)
y = list(broad_phase_of_flight['Percent.Serious.and.Fatal'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percent Serious or Fatal")

ax.set_xlabel('Broad Phase of Flight')

ax.set_title("Percent Serious or Fatal by Broad Phase of Flight")
# Out:
# Text(0.5, 1.0, 'Percent Serious or Fatal by Broad Phase of Flight')

# %%
#engine number bar graph
engine_num.sort_values(by = 'Percent.Uninjured')

x = list(engine_num.index)
y = list(engine_num['Percent.Serious.and.Fatal'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percent Serious or Fatal")

ax.set_xlabel('Engine Number')

ax.set_title("Percent Serious or Fatal by Engine Number")
# Out:
# Text(0.5, 1.0, 'Percent Serious or Fatal by Engine Number')

# %%
engine_num
# Out:
#                    Percent.Serious.and.Fatal  Percent.Uninjured
# Number.of.Engines
# 2.0                                30.873148          65.546574
# 1.0                                24.508043          65.909508
# 4.0                                 5.105251          94.851804

# %%
#location bar graph


x1 = list(location_of_flight.index)[:10]
y1= list(location_of_flight['Percent.Serious.and.Fatal'])[:10]

y2 = list(df_location['Location'].value_counts())[:10]
x2 = list(df_location['Location'].value_counts().index)[:10]

x3 = list(location_of_flight.index)[-10:]
y3= list(location_of_flight['Percent.Serious.and.Fatal'])[-10:]

y4 = list(df_location['Location'].value_counts())[-10:]
x4 = list(df_location['Location'].value_counts().index)[-10:]

fig, ax = plt.subplots(1,2, figsize = (12,8), sharey = True)

# first graph
ax[0].bar(x1, y1)

ax[0].tick_params(axis="x", labelrotation=90)

ax[0].set_ylabel("Percent Serious or Fatal")

ax[0].set_xlabel('Location')

ax[0].set_title("Locations with the Best Major Injury Percentage")


# third graph
                       
ax[1].bar(x3, y3)

ax[1].tick_params(axis="x", labelrotation=90)

ax[1].set_ylabel("Percent Serious or Fatal")

ax[1].set_xlabel('Location')

ax[1].set_title("Locations with the Worst Major Injury Percentage")
# Out:
# Text(0.5, 1.0, 'Locations with the Worst Major Injury Percentage')

# %%
x = df_trimmed['Percent.Uninjured']
y = df_trimmed['Percent.Serious.and.Fatal']

fig, ax = plt.subplots(figsize=(12, 8))

ax.scatter(x=x, y=y, alpha=0.3)

ax.set_xlabel("Percent Uninjured")
ax.set_ylabel("Percent Seriously or Fatally Injuired")
ax.set_title("Correlation Between Uninjured and Seriously to Fatally Injured");
