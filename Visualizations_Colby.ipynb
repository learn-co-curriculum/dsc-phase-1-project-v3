# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#useful dataframes created in cleaning and processing
engine_type
purpose_of_flight
weather_condition
broad_phase_of_flight
engine_num
# Out:
#                    Percent.Serious.and.Fatal  Percent.Uninjured
# Number.of.Engines
# 4.0                                 5.105251          94.851804
# 1.0                                24.503083          65.906288
# 2.0                                30.873148          65.546574

# %%
#


x1 = top_ten_small_planes_model
y1 = top_ten_small_planes_percunij

x2 = list(by_model_final_over_20.index)
y2 = list(by_model_final_over_20['Percent.Uninjured'])

fig, ax = plt.subplots(1, 2, figsize = (12,8))

# Plot data

ax[0].bar(x1, y1)
ax[1].bar(x2, y2)

# Customize appearance
ax[0].tick_params(axis="x", labelrotation=90)
ax[0].set_ylabel("Percentage Uninjured")
ax[0].set_xlabel("Plane Model")
ax[0].set_title("Percentage Uninjured in Planes with a Capacity < 20") 
ax[1].tick_params(axis="x", labelrotation=90)
ax[1].set_ylabel("Percentage Uninjured")
ax[1].set_xlabel("Plane Model")
ax[1].set_title("Percentage Uninjured in Planes with a Capacity > 20")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured in Planes with a Capacity > 20')

# %%
df_trimmed
# Out:
#        Unnamed: 0.1  Unnamed: 0        Event.Id Investigation.Type  \
# 0                 0           7  20020909X01562           Accident
# 1                 1          12  20020917X02148           Accident
# 2                 2          17  20020917X01656           Accident
# 3                 3          18  20020917X02481           Accident
# 4                 4          20  20020917X01894           Accident
# ...             ...         ...             ...                ...
# 11373         11373       90303  20221206106424           Accident
# 11374         11374       90305  20221206106419           Accident
# 11375         11375       90316  20221213106447           Accident
# 11376         11376       90324  20221212106444           Accident
# 11377         11377       90332  20221215106463           Accident
#
#        Event.Date Location Injury.Severity Aircraft.damage  \
# 0      1982-01-01       WA       Non-Fatal     Substantial
# 1      1982-01-02       LA       Non-Fatal       Destroyed
# 2      1982-01-02       AK        Fatal(3)       Destroyed
# 3      1982-01-02       PA       Non-Fatal     Substantial
# 4      1982-01-02       MI       Non-Fatal     Substantial
# ...           ...      ...             ...             ...
# 11373  2022-12-04       MN       Non-Fatal     Substantial
# 11374  2022-12-05       OK           Fatal       Destroyed
# 11375  2022-12-08       GA       Non-Fatal     Substantial
# 11376  2022-12-12       TN       Non-Fatal     Substantial
# 11377  2022-12-14       PR       Non-Fatal     Substantial
#
#                      Make  Number.of.Engines  ... Total.Uninjured  \
# 0                  cessna                1.0  ...             2.0
# 1                bellanca                1.0  ...             0.0
# 2                  cessna                1.0  ...             0.0
# 3                  cessna                1.0  ...             1.0
# 4                  cessna                1.0  ...             1.0
# ...                   ...                ...  ...             ...
# 11373              cessna                1.0  ...             2.0
# 11374               beech                1.0  ...             0.0
# 11375               beech                1.0  ...             2.0
# 11376              cessna                1.0  ...             1.0
# 11377  cirrus design corp                1.0  ...             1.0
#
#       Weather.Condition  Broad.phase.of.flight   Report.Status  Num.Passenger  \
# 0                   VMC                Takeoff  Probable Cause            2.0
# 1                   IMC                 Cruise  Probable Cause            1.0
# 2                   VMC                Unknown  Probable Cause            3.0
# 3                   VMC                   Taxi  Probable Cause            1.0
# 4                   VMC                Takeoff  Probable Cause            1.0
# ...                 ...                    ...             ...            ...
# 11373               VMC                    NaN             NaN            2.0
# 11374               VMC                    NaN             NaN            3.0
# 11375               VMC                    NaN             NaN            2.0
# 11376               VMC                    NaN             NaN            1.0
# 11377               VMC                    NaN             NaN            1.0
#
#        Total.Injured Percent.Serious.and.Fatal Percent.Uninjured  \
# 0                0.0                       0.0             100.0
# 1                1.0                       0.0               0.0
# 2                3.0                     100.0               0.0
# 3                0.0                       0.0             100.0
# 4                0.0                       0.0             100.0
# ...              ...                       ...               ...
# 11373            0.0                       0.0             100.0
# 11374            3.0                     100.0               0.0
# 11375            0.0                       0.0             100.0
# 11376            0.0                       0.0             100.0
# 11377            0.0                       0.0             100.0
#
#                    Make.Model  Max.Capacity
# 0                   cessna140             2
# 1              bellanca17-30A             5
# 2                   cessna180             6
# 3                   cessna172             4
# 4                   cessna152             3
# ...                       ...           ...
# 11373             cessnaA185F             6
# 11374               beechF33A             5
# 11375                beechA36             4
# 11376               cessna172             4
# 11377  cirrus design corpSR22             5
#
# [11378 rows x 25 columns]

# %%
#bar graph by engine type
engine_type

x = list(engine_type.index)
y = list(engine_type['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Engine Type')

ax.set_title("Percentage Uninjured by Engine Type")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Engine Type')

# %% [raw]
# #bar graph for Purpose of flight
#
# x = list(purpose_of_flight.index)
# y = list(purpose_of_flight['Percent.Uninjured'])
# fig, ax = plt.subplots()
#
# # Plot data
# ax.bar(x, y)
#
# # Customize appearance
# ax.tick_params(axis="x", labelrotation=90)
#
# ax.set_ylabel("Percentage Uninjured")
#
# ax.set_xlabel('Purpose of Flight')
#
# ax.set_title("Percentage Uninjured by Purpose of Flight")

# %%
#Bar graph by weather condition
weather_condition

x = list(weather_condition.index)
y = list(weather_condition['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Weather Condition')

ax.set_title("Percentage Uninjured by Weather Condition")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Weather Condition')

# %%
#broad phase of flight bar graph
broad_phase_of_flight

x = list(broad_phase_of_flight.index)
y = list(broad_phase_of_flight['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Broad Phase of Flight')

ax.set_title("Percentage Uninjured by Broad Phase of Flight")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Broad Phase of Flight')

# %%
#engine number bar graph
engine_num.sort_values(by = 'Percent.Uninjured')

x = list(engine_num.index)
y = list(engine_num['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Engine Number')

ax.set_title("Percentage Uninjured by Engine Number")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Engine Number')

# %%
#location bar graph


x1 = list(location_of_flight.index)[-10:]
y1 = list(location_of_flight['Percent.Uninjured'])[-10:]

x2 = list(df_location['Location'].value_counts().index)[-10:]
y2 = list(df_location['Location'].value_counts().values)[-10:]

x3 = list(location_of_flight.index)[:10]
y3 = list(location_of_flight['Percent.Uninjured'])[:10]

x4 = list(df_location['Location'].value_counts().index)[:10]
y4 = list(df_location['Location'].value_counts().values)[:10]


fig, ax = plt.subplots( 2, 2, figsize = (12,8))

# Plot data
ax[0,0].bar(x1, y1)
ax[0,1].bar(x2, y2)
ax[1,0].bar(x3, y3)
ax[1,1].bar(x4, y4)
# Customize appearance
ax[0,0].tick_params(axis="x", labelrotation=90)
ax[0,0].set_ylabel("Percentage Uninjured")
ax[0,0].set_xlabel('Location')
ax[0,0].set_title("States Highest Uninjured Percentage")

ax[0,1].tick_params(axis="x", labelrotation=90)
ax[0,1].set_ylabel("Number of Accidents")
ax[0,1].set_xlabel('Location')
ax[0,1].set_title("States with Least Accidents")

ax[1,0].tick_params(axis="x", labelrotation=90)
ax[1,0].set_ylabel("Percentage Uninjured")
ax[1,0].set_xlabel('Location')
ax[1,0].set_title("States Lowest Uninjured Percentage")

ax[1,1].tick_params(axis="x", labelrotation=90)
ax[1,1].set_ylabel("Percentage Uninjured")
ax[1,1].set_xlabel('Location')
ax[1,1].set_title("States with Most Accidents")

fig.tight_layout()
