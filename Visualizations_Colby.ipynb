# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#useful dataframes created in cleaning and processing
engine_type
purpose_of_flight
weather_condition
broad_phase_of_flight
engine_num
# Out:
#                    Percent.Serious.and.Fatal  Percent.Uninjured
# Number.of.Engines
# 4.0                                 5.105251          94.851804
# 1.0                                24.503083          65.906288
# 2.0                                30.873148          65.546574

# %%
#
by_model_final_sub_20
by_model_final_over_20

x1 = list(by_model_final_sub_20.index)
y1 = list(by_model_final_sub_20['Percent.Uninjured'])

x2 = list(by_model_final_over_20.index)
y2 = list(by_model_final_over_20['Percent.Uninjured'])

fig, ax = plt.subplots(1, 2, figsize = (12,8))

# Plot data

ax[0].bar(x1, y1)
ax[1].bar(x2, y2)

# Customize appearance
ax[0].tick_params(axis="x", labelrotation=90)
ax[0].set_ylabel("Percentage Uninjured")
ax[0].set_xlabel("Plane Model")
ax[0].set_title("Percentage Uninjured in Planes with a Capacity < 20") 
ax[1].tick_params(axis="x", labelrotation=90)
ax[1].set_ylabel("Percentage Uninjured")
ax[1].set_xlabel("Plane Model")
ax[1].set_title("Percentage Uninjured in Planes with a Capacity > 20")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 9
#       6 fig, ax = plt.subplots(1, 3, figsize = (12,8))
#       8 # Plot data
# ----> 9 ax.bar(x, y)
#      10 # Customize appearance
#      11 ax.tick_params(axis="x", labelrotation=90)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'bar'

# %%
df_trimmed
# Out:
#              Event.Id Investigation.Type  Event.Date          Location  \
# 7      20020909X01562           Accident  1982-01-01       PULLMAN, WA
# 12     20020917X02148           Accident  1982-01-02         HOMER, LA
# 17     20020917X01656           Accident  1982-01-02       SKWENTA, AK
# 18     20020917X02481           Accident  1982-01-02       GALETON, PA
# 20     20020917X01894           Accident  1982-01-02     YPSILANTI, MI
# ...               ...                ...         ...               ...
# 90303  20221206106424           Accident  2022-12-04  Fergus Falls, MN
# 90305  20221206106419           Accident  2022-12-05         Yukon, OK
# 90316  20221213106447           Accident  2022-12-08     Covington, GA
# 90324  20221212106444           Accident  2022-12-12     Knoxville, TN
# 90332  20221215106463           Accident  2022-12-14      San Juan, PR
#
#       Injury.Severity Aircraft.damage                Make  Number.of.Engines  \
# 7           Non-Fatal     Substantial              cessna                1.0
# 12          Non-Fatal       Destroyed            bellanca                1.0
# 17           Fatal(3)       Destroyed              cessna                1.0
# 18          Non-Fatal     Substantial              cessna                1.0
# 20          Non-Fatal     Substantial              cessna                1.0
# ...               ...             ...                 ...                ...
# 90303       Non-Fatal     Substantial              cessna                1.0
# 90305           Fatal       Destroyed               beech                1.0
# 90316       Non-Fatal     Substantial               beech                1.0
# 90324       Non-Fatal     Substantial              cessna                1.0
# 90332       Non-Fatal     Substantial  cirrus design corp                1.0
#
#          Engine.Type Purpose.of.flight  ...  Total.Minor.Injuries  \
# 7      Reciprocating          Personal  ...                   0.0
# 12     Reciprocating          Personal  ...                   1.0
# 17     Reciprocating          Personal  ...                   0.0
# 18     Reciprocating          Personal  ...                   0.0
# 20     Reciprocating     Instructional  ...                   0.0
# ...              ...               ...  ...                   ...
# 90303            NaN          Personal  ...                   0.0
# 90305            NaN          Personal  ...                   0.0
# 90316            NaN          Personal  ...                   0.0
# 90324            NaN     Instructional  ...                   0.0
# 90332            NaN          Personal  ...                   0.0
#
#        Total.Uninjured  Weather.Condition  Broad.phase.of.flight  \
# 7                  2.0                VMC                Takeoff
# 12                 0.0                IMC                 Cruise
# 17                 0.0                VMC                Unknown
# 18                 1.0                VMC                   Taxi
# 20                 1.0                VMC                Takeoff
# ...                ...                ...                    ...
# 90303              2.0                VMC                    NaN
# 90305              0.0                VMC                    NaN
# 90316              2.0                VMC                    NaN
# 90324              1.0                VMC                    NaN
# 90332              1.0                VMC                    NaN
#
#         Report.Status Num.Passenger Total.Injured  Percent.Serious.and.Fatal  \
# 7      Probable Cause           2.0           0.0                        0.0
# 12     Probable Cause           1.0           1.0                        0.0
# 17     Probable Cause           3.0           3.0                      100.0
# 18     Probable Cause           1.0           0.0                        0.0
# 20     Probable Cause           1.0           0.0                        0.0
# ...               ...           ...           ...                        ...
# 90303             NaN           2.0           0.0                        0.0
# 90305             NaN           3.0           3.0                      100.0
# 90316             NaN           2.0           0.0                        0.0
# 90324             NaN           1.0           0.0                        0.0
# 90332             NaN           1.0           0.0                        0.0
#
#        Percent.Uninjured              Make.Model
# 7                  100.0               cessna140
# 12                   0.0          bellanca17-30A
# 17                   0.0               cessna180
# 18                 100.0               cessna172
# 20                 100.0               cessna152
# ...                  ...                     ...
# 90303              100.0             cessnaA185F
# 90305                0.0               beechF33A
# 90316              100.0                beechA36
# 90324              100.0               cessna172
# 90332              100.0  cirrus design corpSR22
#
# [11378 rows x 22 columns]

# %%
#bar graph by engine type
engine_type

x = list(engine_type.index)
y = list(engine_type['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Engine Type')

ax.set_title("Percentage Uninjured by Engine Type")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Engine Type')

# %% [raw]
# #bar graph for Purpose of flight
#
# x = list(purpose_of_flight.index)
# y = list(purpose_of_flight['Percent.Uninjured'])
# fig, ax = plt.subplots()
#
# # Plot data
# ax.bar(x, y)
#
# # Customize appearance
# ax.tick_params(axis="x", labelrotation=90)
#
# ax.set_ylabel("Percentage Uninjured")
#
# ax.set_xlabel('Purpose of Flight')
#
# ax.set_title("Percentage Uninjured by Purpose of Flight")

# %%
#Bar graph by weather condition
weather_condition

x = list(weather_condition.index)
y = list(weather_condition['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Weather Condition')

ax.set_title("Percentage Uninjured by Weather Condition")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Weather Condition')

# %%
#broad phase of flight bar graph
broad_phase_of_flight

x = list(broad_phase_of_flight.index)
y = list(broad_phase_of_flight['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Broad Phase of Flight')

ax.set_title("Percentage Uninjured by Broad Phase of Flight")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Broad Phase of Flight')

# %%
#engine number bar graph
engine_num.sort_values(by = 'Percent.Uninjured')

x = list(engine_num.index)
y = list(engine_num['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Engine Number')

ax.set_title("Percentage Uninjured by Engine Number")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Engine Number')

# %%
#location bar graph


x = list(location_of_flight.index)
y = list(location_of_flight['Percent.Uninjured'])
fig, ax = plt.subplots()

# Plot data
ax.bar(x, y)

# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_xlabel('Location')

ax.set_title("Percentage Uninjured by Location")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured by Location')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 158 (\x9e) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/events.py:82: UserWarning: Glyph 150 (\x96) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 158 (\x9e) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
