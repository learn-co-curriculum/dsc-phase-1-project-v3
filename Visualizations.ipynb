# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = list_of_counts_per_model
y = list_perc_uninj


fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=x, y=y, alpha=0.3
)

ax.set_xlabel("# of Accidents + Incidents")
ax.set_ylabel("Percentage Uninjured")
# Out:
# Text(0, 0.5, 'Percentage Uninjured')

# %%
make_model_mean_percentuninj.isna().sum()
# Out:
# Percent.Uninjured    0
# dtype: int64

# %%
x = list_of_models
y = list_perc_uninj
fig, ax = plt.subplots()

# Create variables for easier reuse

# Plot data
ax.bar(x, y)
# Customize appearance
ax.tick_params(axis="x", labelrotation=90)

ax.set_ylabel("Percentage Uninjured")

ax.set_title("Percentage Uninjured")
# Out:
# Text(0.5, 1.0, 'Percentage Uninjured')
